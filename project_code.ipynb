# %%
import requests
import json
import pandas as pd

# %%
print("COVID19 Analysis")
country = input("Enter a country: ")
country = country.lower()
cases = input("Enter confirmed, recovered, or deaths: ")
cases = cases.lower()
date = input("Enter a date: ")
url = 'https://api.covid19api.com/live/country/'+country+'/status/'+cases+'/date/'+date+'T00:00:00Z'
response = requests.get(url)
print(response.url)
stats = response.json()

response.json()
# Out:
# COVID19 Analysis
# Enter a country: united states of america
# Enter confirmed, recovered, or deaths: confirmed
# Enter a date: 2020-04-20
# https://api.covid19api.com/live/country/united%20states%20of%20america/status/confirmed/date/2020-04-20T00:00:00Z
# [{'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Maryland',
#   'City': '',
#   'CityCode': '',
#   'Lat': '39.06',
#   'Lon': '-76.8',
#   'Confirmed': 13684,
#   'Deaths': 582,
#   'Recovered': 0,
#   'Active': 13102,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Wyoming',
#   'City': '',
#   'CityCode': '',
#   'Lat': '42.76',
#   'Lon': '-107.3',
#   'Confirmed': 317,
#   'Deaths': 2,
#   'Recovered': 0,
#   'Active': 315,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Northern Mariana Islands',
#   'City': '',
#   'CityCode': '',
#   'Lat': '15.1',
#   'Lon': '145.67',
#   'Confirmed': 14,
#   'Deaths': 2,
#   'Recovered': 0,
#   'Active': 12,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Kansas',
#   'City': '',
#   'CityCode': '',
#   'Lat': '38.53',
#   'Lon': '-96.73',
#   'Confirmed': 2048,
#   'Deaths': 102,
#   'Recovered': 0,
#   'Active': 1946,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Michigan',
#   'City': '',
#   'CityCode': '',
#   'Lat': '43.33',
#   'Lon': '-84.54',
#   'Confirmed': 32000,
#   'Deaths': 2468,
#   'Recovered': 0,
#   'Active': 29532,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Nevada',
#   'City': '',
#   'CityCode': '',
#   'Lat': '38.31',
#   'Lon': '-117.06',
#   'Confirmed': 3830,
#   'Deaths': 159,
#   'Recovered': 0,
#   'Active': 3671,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Mississippi',
#   'City': '',
#   'CityCode': '',
#   'Lat': '32.74',
#   'Lon': '-89.68',
#   'Confirmed': 4512,
#   'Deaths': 169,
#   'Recovered': 0,
#   'Active': 4343,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'District of Columbia',
#   'City': '',
#   'CityCode': '',
#   'Lat': '38.9',
#   'Lon': '-77.03',
#   'Confirmed': 2927,
#   'Deaths': 105,
#   'Recovered': 0,
#   'Active': 2822,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Ohio',
#   'City': '',
#   'CityCode': '',
#   'Lat': '40.39',
#   'Lon': '-82.76',
#   'Confirmed': 12919,
#   'Deaths': 509,
#   'Recovered': 0,
#   'Active': 12410,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Massachusetts',
#   'City': '',
#   'CityCode': '',
#   'Lat': '42.23',
#   'Lon': '-71.53',
#   'Confirmed': 38077,
#   'Deaths': 1706,
#   'Recovered': 0,
#   'Active': 36371,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Kentucky',
#   'City': '',
#   'CityCode': '',
#   'Lat': '37.67',
#   'Lon': '-84.67',
#   'Confirmed': 3050,
#   'Deaths': 154,
#   'Recovered': 0,
#   'Active': 2896,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Alabama',
#   'City': '',
#   'CityCode': '',
#   'Lat': '32.32',
#   'Lon': '-86.9',
#   'Confirmed': 5078,
#   'Deaths': 164,
#   'Recovered': 0,
#   'Active': 4914,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Georgia',
#   'City': '',
#   'CityCode': '',
#   'Lat': '33.04',
#   'Lon': '-83.64',
#   'Confirmed': 19399,
#   'Deaths': 775,
#   'Recovered': 0,
#   'Active': 18624,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Idaho',
#   'City': '',
#   'CityCode': '',
#   'Lat': '44.24',
#   'Lon': '-114.48',
#   'Confirmed': 1736,
#   'Deaths': 48,
#   'Recovered': 0,
#   'Active': 1688,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Florida',
#   'City': '',
#   'CityCode': '',
#   'Lat': '27.77',
#   'Lon': '-81.69',
#   'Confirmed': 27058,
#   'Deaths': 823,
#   'Recovered': 0,
#   'Active': 26235,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Utah',
#   'City': '',
#   'CityCode': '',
#   'Lat': '40.15',
#   'Lon': '-111.86',
#   'Confirmed': 3213,
#   'Deaths': 28,
#   'Recovered': 0,
#   'Active': 3185,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Iowa',
#   'City': '',
#   'CityCode': '',
#   'Lat': '42.01',
#   'Lon': '-93.21',
#   'Confirmed': 3159,
#   'Deaths': 79,
#   'Recovered': 0,
#   'Active': 3080,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Rhode Island',
#   'City': '',
#   'CityCode': '',
#   'Lat': '41.68',
#   'Lon': '-71.51',
#   'Confirmed': 5090,
#   'Deaths': 155,
#   'Recovered': 0,
#   'Active': 4935,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Pennsylvania',
#   'City': '',
#   'CityCode': '',
#   'Lat': '40.59',
#   'Lon': '-77.21',
#   'Confirmed': 33914,
#   'Deaths': 1348,
#   'Recovered': 0,
#   'Active': 32566,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Wisconsin',
#   'City': '',
#   'CityCode': '',
#   'Lat': '44.27',
#   'Lon': '-89.62',
#   'Confirmed': 4499,
#   'Deaths': 230,
#   'Recovered': 0,
#   'Active': 4269,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Texas',
#   'City': '',
#   'CityCode': '',
#   'Lat': '31.05',
#   'Lon': '-97.56',
#   'Confirmed': 19751,
#   'Deaths': 507,
#   'Recovered': 0,
#   'Active': 19244,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Missouri',
#   'City': '',
#   'CityCode': '',
#   'Lat': '38.46',
#   'Lon': '-92.29',
#   'Confirmed': 5890,
#   'Deaths': 200,
#   'Recovered': 0,
#   'Active': 5690,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Connecticut',
#   'City': '',
#   'CityCode': '',
#   'Lat': '41.6',
#   'Lon': '-72.76',
#   'Confirmed': 19815,
#   'Deaths': 1331,
#   'Recovered': 0,
#   'Active': 18484,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Virginia',
#   'City': '',
#   'CityCode': '',
#   'Lat': '37.77',
#   'Lon': '-78.17',
#   'Confirmed': 8990,
#   'Deaths': 300,
#   'Recovered': 0,
#   'Active': 8690,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Virgin Islands',
#   'City': '',
#   'CityCode': '',
#   'Lat': '18.34',
#   'Lon': '-64.9',
#   'Confirmed': 53,
#   'Deaths': 3,
#   'Recovered': 0,
#   'Active': 50,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'New York',
#   'City': '',
#   'CityCode': '',
#   'Lat': '42.17',
#   'Lon': '-74.95',
#   'Confirmed': 253060,
#   'Deaths': 18611,
#   'Recovered': 0,
#   'Active': 234449,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Tennessee',
#   'City': '',
#   'CityCode': '',
#   'Lat': '35.75',
#   'Lon': '-86.69',
#   'Confirmed': 7238,
#   'Deaths': 152,
#   'Recovered': 0,
#   'Active': 7086,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'West Virginia',
#   'City': '',
#   'CityCode': '',
#   'Lat': '38.49',
#   'Lon': '-80.95',
#   'Confirmed': 902,
#   'Deaths': 24,
#   'Recovered': 0,
#   'Active': 878,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'South Dakota',
#   'City': '',
#   'CityCode': '',
#   'Lat': '44.3',
#   'Lon': '-99.44',
#   'Confirmed': 1685,
#   'Deaths': 7,
#   'Recovered': 0,
#   'Active': 1678,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'New Mexico',
#   'City': '',
#   'CityCode': '',
#   'Lat': '34.84',
#   'Lon': '-106.25',
#   'Confirmed': 1971,
#   'Deaths': 58,
#   'Recovered': 0,
#   'Active': 1913,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Grand Princess',
#   'City': '',
#   'CityCode': '',
#   'Lat': '37.65',
#   'Lon': '-122.67',
#   'Confirmed': 103,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 103,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Oklahoma',
#   'City': '',
#   'CityCode': '',
#   'Lat': '35.57',
#   'Lon': '-96.93',
#   'Confirmed': 2680,
#   'Deaths': 143,
#   'Recovered': 0,
#   'Active': 2537,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'California',
#   'City': '',
#   'CityCode': '',
#   'Lat': '36.12',
#   'Lon': '-119.68',
#   'Confirmed': 33686,
#   'Deaths': 1225,
#   'Recovered': 0,
#   'Active': 32461,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Hawaii',
#   'City': '',
#   'CityCode': '',
#   'Lat': '21.09',
#   'Lon': '-157.5',
#   'Confirmed': 584,
#   'Deaths': 10,
#   'Recovered': 0,
#   'Active': 574,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Alaska',
#   'City': '',
#   'CityCode': '',
#   'Lat': '61.37',
#   'Lon': '-152.4',
#   'Confirmed': 321,
#   'Deaths': 9,
#   'Recovered': 0,
#   'Active': 312,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Guam',
#   'City': '',
#   'CityCode': '',
#   'Lat': '13.44',
#   'Lon': '144.79',
#   'Confirmed': 136,
#   'Deaths': 5,
#   'Recovered': 0,
#   'Active': 131,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Vermont',
#   'City': '',
#   'CityCode': '',
#   'Lat': '44.05',
#   'Lon': '-72.71',
#   'Confirmed': 816,
#   'Deaths': 38,
#   'Recovered': 0,
#   'Active': 778,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'US Military',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 5575,
#   'Deaths': 22,
#   'Recovered': 0,
#   'Active': 5553,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Minnesota',
#   'City': '',
#   'CityCode': '',
#   'Lat': '45.69',
#   'Lon': '-93.9',
#   'Confirmed': 2470,
#   'Deaths': 143,
#   'Recovered': 0,
#   'Active': 2327,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Montana',
#   'City': '',
#   'CityCode': '',
#   'Lat': '46.92',
#   'Lon': '-110.45',
#   'Confirmed': 433,
#   'Deaths': 10,
#   'Recovered': 0,
#   'Active': 423,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'New Hampshire',
#   'City': '',
#   'CityCode': '',
#   'Lat': '43.45',
#   'Lon': '-71.56',
#   'Confirmed': 1447,
#   'Deaths': 42,
#   'Recovered': 0,
#   'Active': 1405,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Indiana',
#   'City': '',
#   'CityCode': '',
#   'Lat': '39.85',
#   'Lon': '-86.26',
#   'Confirmed': 11688,
#   'Deaths': 577,
#   'Recovered': 0,
#   'Active': 11111,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Oregon',
#   'City': '',
#   'CityCode': '',
#   'Lat': '44.57',
#   'Lon': '-122.07',
#   'Confirmed': 1956,
#   'Deaths': 75,
#   'Recovered': 0,
#   'Active': 1881,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Arizona',
#   'City': '',
#   'CityCode': '',
#   'Lat': '33.73',
#   'Lon': '-111.43',
#   'Confirmed': 5068,
#   'Deaths': 191,
#   'Recovered': 0,
#   'Active': 4877,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Arkansas',
#   'City': '',
#   'CityCode': '',
#   'Lat': '34.97',
#   'Lon': '-92.37',
#   'Confirmed': 1971,
#   'Deaths': 42,
#   'Recovered': 0,
#   'Active': 1929,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Washington',
#   'City': '',
#   'CityCode': '',
#   'Lat': '47.4',
#   'Lon': '-121.49',
#   'Confirmed': 12264,
#   'Deaths': 656,
#   'Recovered': 0,
#   'Active': 11608,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'North Dakota',
#   'City': '',
#   'CityCode': '',
#   'Lat': '47.53',
#   'Lon': '-99.78',
#   'Confirmed': 627,
#   'Deaths': 9,
#   'Recovered': 0,
#   'Active': 618,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'North Carolina',
#   'City': '',
#   'CityCode': '',
#   'Lat': '35.63',
#   'Lon': '-79.81',
#   'Confirmed': 6895,
#   'Deaths': 218,
#   'Recovered': 0,
#   'Active': 6677,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Maine',
#   'City': '',
#   'CityCode': '',
#   'Lat': '44.69',
#   'Lon': '-69.38',
#   'Confirmed': 875,
#   'Deaths': 35,
#   'Recovered': 0,
#   'Active': 840,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Delaware',
#   'City': '',
#   'CityCode': '',
#   'Lat': '39.32',
#   'Lon': '-75.51',
#   'Confirmed': 2745,
#   'Deaths': 72,
#   'Recovered': 0,
#   'Active': 2673,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Nebraska',
#   'City': '',
#   'CityCode': '',
#   'Lat': '41.13',
#   'Lon': '-98.27',
#   'Confirmed': 1648,
#   'Deaths': 33,
#   'Recovered': 0,
#   'Active': 1615,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Colorado',
#   'City': '',
#   'CityCode': '',
#   'Lat': '39.06',
#   'Lon': '-105.31',
#   'Confirmed': 9730,
#   'Deaths': 420,
#   'Recovered': 0,
#   'Active': 9310,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Puerto Rico',
#   'City': '',
#   'CityCode': '',
#   'Lat': '18.22',
#   'Lon': '-66.59',
#   'Confirmed': 1252,
#   'Deaths': 63,
#   'Recovered': 0,
#   'Active': 1189,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'South Carolina',
#   'City': '',
#   'CityCode': '',
#   'Lat': '33.86',
#   'Lon': '-80.95',
#   'Confirmed': 4439,
#   'Deaths': 124,
#   'Recovered': 0,
#   'Active': 4315,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'New Jersey',
#   'City': '',
#   'CityCode': '',
#   'Lat': '40.3',
#   'Lon': '-74.52',
#   'Confirmed': 88806,
#   'Deaths': 4520,
#   'Recovered': 0,
#   'Active': 84286,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Diamond Princess',
#   'City': '',
#   'CityCode': '',
#   'Lat': '35.44',
#   'Lon': '139.64',
#   'Confirmed': 49,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 49,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Louisiana',
#   'City': '',
#   'CityCode': '',
#   'Lat': '31.17',
#   'Lon': '-91.87',
#   'Confirmed': 24523,
#   'Deaths': 1328,
#   'Recovered': 0,
#   'Active': 23195,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Province': 'Illinois',
#   'City': '',
#   'CityCode': '',
#   'Lat': '40.35',
#   'Lon': '-88.99',
#   'Confirmed': 31508,
#   'Deaths': 1349,
#   'Recovered': 0,
#   'Active': 30159,
#   'Date': '2020-04-21T00:00:00Z'}]

# %%
url_1 = 'https://api.covid19api.com/summary'
response_summary = requests.get(url_1)
summary = response_summary.json()
response_summary.json()
# Out:
# {'Global': {'NewConfirmed': 70871,
#   'TotalConfirmed': 2470922,
#   'NewDeaths': 4940,
#   'TotalDeaths': 169952,
#   'NewRecovered': 21835,
#   'TotalRecovered': 645094},
#  'Countries': [{'Country': 'ALA Aland Islands',
#    'CountryCode': 'AX',
#    'Slug': 'ala-aland-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 30,
#    'TotalConfirmed': 1026,
#    'NewDeaths': 3,
#    'TotalDeaths': 36,
#    'NewRecovered': 4,
#    'TotalRecovered': 135,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 22,
#    'TotalConfirmed': 584,
#    'NewDeaths': 0,
#    'TotalDeaths': 26,
#    'NewRecovered': 13,
#    'TotalRecovered': 327,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 89,
#    'TotalConfirmed': 2718,
#    'NewDeaths': 9,
#    'TotalDeaths': 384,
#    'NewRecovered': 52,
#    'TotalRecovered': 1099,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'American Samoa',
#    'CountryCode': 'AS',
#    'Slug': 'american-samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 717,
#    'NewDeaths': 1,
#    'TotalDeaths': 37,
#    'NewRecovered': 13,
#    'TotalRecovered': 248,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 6,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Anguilla',
#    'CountryCode': 'AI',
#    'Slug': 'anguilla',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Antarctica',
#    'CountryCode': 'AQ',
#    'Slug': 'antarctica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 102,
#    'TotalConfirmed': 2941,
#    'NewDeaths': 4,
#    'TotalDeaths': 136,
#    'NewRecovered': 28,
#    'TotalRecovered': 737,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 48,
#    'TotalConfirmed': 1339,
#    'NewDeaths': 2,
#    'TotalDeaths': 22,
#    'NewRecovered': 35,
#    'TotalRecovered': 580,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Aruba',
#    'CountryCode': 'AW',
#    'Slug': 'aruba',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6547,
#    'NewDeaths': 0,
#    'TotalDeaths': 67,
#    'NewRecovered': 0,
#    'TotalRecovered': 4124,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 46,
#    'TotalConfirmed': 14795,
#    'NewDeaths': 18,
#    'TotalDeaths': 470,
#    'NewRecovered': 130,
#    'TotalRecovered': 10631,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 38,
#    'TotalConfirmed': 1436,
#    'NewDeaths': 0,
#    'TotalDeaths': 19,
#    'NewRecovered': 79,
#    'TotalRecovered': 791,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 60,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 1,
#    'TotalRecovered': 11,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 26,
#    'TotalConfirmed': 1907,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 10,
#    'TotalRecovered': 769,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 492,
#    'TotalConfirmed': 2948,
#    'NewDeaths': 10,
#    'TotalDeaths': 101,
#    'NewRecovered': 10,
#    'TotalRecovered': 85,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 75,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 2,
#    'TotalRecovered': 19,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 1485,
#    'TotalConfirmed': 6264,
#    'NewDeaths': 4,
#    'TotalDeaths': 51,
#    'NewRecovered': 20,
#    'TotalRecovered': 514,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 1487,
#    'TotalConfirmed': 39983,
#    'NewDeaths': 145,
#    'TotalDeaths': 5828,
#    'NewRecovered': 138,
#    'TotalRecovered': 8895,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 19,
#    'TotalConfirmed': 54,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 9,
#    'TotalRecovered': 27,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Bermuda',
#    'CountryCode': 'BM',
#    'Slug': 'bermuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 44,
#    'TotalConfirmed': 564,
#    'NewDeaths': 1,
#    'TotalDeaths': 33,
#    'NewRecovered': 0,
#    'TotalRecovered': 31,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 24,
#    'TotalConfirmed': 1309,
#    'NewDeaths': 1,
#    'TotalDeaths': 49,
#    'NewRecovered': 34,
#    'TotalRecovered': 381,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Bouvet Island',
#    'CountryCode': 'BV',
#    'Slug': 'bouvet-island',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 2089,
#    'TotalConfirmed': 40743,
#    'NewDeaths': 125,
#    'TotalDeaths': 2587,
#    'NewRecovered': 0,
#    'TotalRecovered': 22130,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'British Indian Ocean Territory',
#    'CountryCode': 'IO',
#    'Slug': 'british-indian-ocean-territory',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'British Virgin Islands',
#    'CountryCode': 'VG',
#    'Slug': 'british-virgin-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 138,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 1,
#    'TotalRecovered': 116,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 35,
#    'TotalConfirmed': 929,
#    'NewDeaths': 1,
#    'TotalDeaths': 43,
#    'NewRecovered': 6,
#    'TotalRecovered': 167,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 581,
#    'NewDeaths': 2,
#    'TotalDeaths': 38,
#    'NewRecovered': 19,
#    'TotalRecovered': 357,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 4,
#    'TotalRecovered': 4,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 122,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 2,
#    'TotalRecovered': 107,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 146,
#    'TotalConfirmed': 1163,
#    'NewDeaths': 0,
#    'TotalDeaths': 42,
#    'NewRecovered': 0,
#    'TotalRecovered': 305,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 2025,
#    'TotalConfirmed': 37658,
#    'NewDeaths': 162,
#    'TotalDeaths': 1726,
#    'NewRecovered': 696,
#    'TotalRecovered': 12543,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 67,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Cayman Islands',
#    'CountryCode': 'KY',
#    'Slug': 'cayman-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 4,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 33,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 8,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 419,
#    'TotalConfirmed': 10507,
#    'NewDeaths': 6,
#    'TotalDeaths': 139,
#    'NewRecovered': 338,
#    'TotalRecovered': 4676,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 83817,
#    'NewDeaths': 0,
#    'TotalDeaths': 4636,
#    'NewRecovered': 55,
#    'TotalRecovered': 77745,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Christmas Island',
#    'CountryCode': 'CX',
#    'Slug': 'christmas-island',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Cocos (Keeling) Islands',
#    'CountryCode': 'CC',
#    'Slug': 'cocos-keeling-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 185,
#    'TotalConfirmed': 3977,
#    'NewDeaths': 10,
#    'TotalDeaths': 189,
#    'NewRecovered': 93,
#    'TotalRecovered': 804,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 17,
#    'TotalConfirmed': 160,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 5,
#    'TotalRecovered': 16,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 332,
#    'NewDeaths': 0,
#    'TotalDeaths': 25,
#    'NewRecovered': 1,
#    'TotalRecovered': 27,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Cook Islands',
#    'CountryCode': 'CK',
#    'Slug': 'cook-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 662,
#    'NewDeaths': 1,
#    'TotalDeaths': 6,
#    'NewRecovered': 12,
#    'TotalRecovered': 124,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 1881,
#    'NewDeaths': 0,
#    'TotalDeaths': 47,
#    'NewRecovered': 62,
#    'TotalRecovered': 771,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 52,
#    'TotalConfirmed': 1087,
#    'NewDeaths': 2,
#    'TotalDeaths': 36,
#    'NewRecovered': 30,
#    'TotalRecovered': 285,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 772,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 0,
#    'TotalRecovered': 81,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 154,
#    'TotalConfirmed': 6900,
#    'NewDeaths': 8,
#    'TotalDeaths': 194,
#    'NewRecovered': 261,
#    'TotalRecovered': 1559,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 847,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 0,
#    'TotalRecovered': 260,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 131,
#    'TotalConfirmed': 7711,
#    'NewDeaths': 9,
#    'TotalDeaths': 364,
#    'NewRecovered': 171,
#    'TotalRecovered': 4499,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 846,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 102,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 8,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 284,
#    'TotalConfirmed': 4964,
#    'NewDeaths': 9,
#    'TotalDeaths': 235,
#    'NewRecovered': 53,
#    'TotalRecovered': 416,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 660,
#    'TotalConfirmed': 10128,
#    'NewDeaths': 33,
#    'TotalDeaths': 507,
#    'NewRecovered': 89,
#    'TotalRecovered': 1150,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 189,
#    'TotalConfirmed': 3333,
#    'NewDeaths': 11,
#    'TotalDeaths': 250,
#    'NewRecovered': 89,
#    'TotalRecovered': 821,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 17,
#    'TotalConfirmed': 218,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 2,
#    'TotalRecovered': 46,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 79,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 3,
#    'TotalRecovered': 7,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 1535,
#    'NewDeaths': 0,
#    'TotalDeaths': 40,
#    'NewRecovered': 1,
#    'TotalRecovered': 165,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 111,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 16,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Falkland Islands (Malvinas)',
#    'CountryCode': 'FK',
#    'Slug': 'falkland-islands-malvinas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Faroe Islands',
#    'CountryCode': 'FO',
#    'Slug': 'faroe-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 18,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 3,
#    'TotalRecovered': 3,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 85,
#    'TotalConfirmed': 3868,
#    'NewDeaths': 4,
#    'TotalDeaths': 98,
#    'NewRecovered': 300,
#    'TotalRecovered': 2000,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 2383,
#    'TotalConfirmed': 156480,
#    'NewDeaths': 548,
#    'TotalDeaths': 20292,
#    'NewRecovered': 853,
#    'TotalRecovered': 38036,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'French Guiana',
#    'CountryCode': 'GF',
#    'Slug': 'french-guiana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'French Polynesia',
#    'CountryCode': 'PF',
#    'Slug': 'french-polynesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'French Southern Territories',
#    'CountryCode': 'TF',
#    'Slug': 'french-southern-territories',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 11,
#    'TotalConfirmed': 120,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 7,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 402,
#    'NewDeaths': 0,
#    'TotalDeaths': 4,
#    'NewRecovered': 2,
#    'TotalRecovered': 95,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 1881,
#    'TotalConfirmed': 147065,
#    'NewDeaths': 276,
#    'TotalDeaths': 4862,
#    'NewRecovered': 3500,
#    'TotalRecovered': 91500,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1042,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 0,
#    'TotalRecovered': 99,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Gibraltar',
#    'CountryCode': 'GI',
#    'Slug': 'gibraltar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 2245,
#    'NewDeaths': 3,
#    'TotalDeaths': 116,
#    'NewRecovered': 0,
#    'TotalRecovered': 269,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Greenland',
#    'CountryCode': 'GL',
#    'Slug': 'greenland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 6,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Guadeloupe',
#    'CountryCode': 'GP',
#    'Slug': 'guadeloupe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Guam',
#    'CountryCode': 'GU',
#    'Slug': 'guam',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 32,
#    'TotalConfirmed': 289,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 21,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Guernsey',
#    'CountryCode': 'GG',
#    'Slug': 'guernsey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 43,
#    'TotalConfirmed': 622,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 35,
#    'TotalRecovered': 122,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 50,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 65,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 9,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 57,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Heard and Mcdonald Islands',
#    'CountryCode': 'HM',
#    'Slug': 'heard-and-mcdonald-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 9,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 477,
#    'NewDeaths': 0,
#    'TotalDeaths': 46,
#    'NewRecovered': 10,
#    'TotalRecovered': 25,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Hong Kong, SAR China',
#    'CountryCode': 'HK',
#    'Slug': 'hong-kong-sar-china',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 68,
#    'TotalConfirmed': 1984,
#    'NewDeaths': 10,
#    'TotalDeaths': 199,
#    'NewRecovered': 17,
#    'TotalRecovered': 267,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 1773,
#    'NewDeaths': 1,
#    'TotalDeaths': 10,
#    'NewRecovered': 71,
#    'TotalRecovered': 1362,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 924,
#    'TotalConfirmed': 18539,
#    'NewDeaths': 33,
#    'TotalDeaths': 592,
#    'NewRecovered': 419,
#    'TotalRecovered': 3273,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 185,
#    'TotalConfirmed': 6760,
#    'NewDeaths': 8,
#    'TotalDeaths': 590,
#    'NewRecovered': 61,
#    'TotalRecovered': 747,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 1294,
#    'TotalConfirmed': 83505,
#    'NewDeaths': 91,
#    'TotalDeaths': 5209,
#    'NewRecovered': 2250,
#    'TotalRecovered': 59273,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 35,
#    'TotalConfirmed': 1574,
#    'NewDeaths': 0,
#    'TotalDeaths': 82,
#    'NewRecovered': 34,
#    'TotalRecovered': 1043,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 401,
#    'TotalConfirmed': 15652,
#    'NewDeaths': 77,
#    'TotalDeaths': 687,
#    'NewRecovered': 0,
#    'TotalRecovered': 77,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Isle of Man',
#    'CountryCode': 'IM',
#    'Slug': 'isle-of-man',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 222,
#    'TotalConfirmed': 13713,
#    'NewDeaths': 5,
#    'TotalDeaths': 177,
#    'NewRecovered': 295,
#    'TotalRecovered': 4049,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 2256,
#    'TotalConfirmed': 181228,
#    'NewDeaths': 454,
#    'TotalDeaths': 24114,
#    'NewRecovered': 1822,
#    'TotalRecovered': 48877,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 50,
#    'TotalConfirmed': 223,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 0,
#    'TotalRecovered': 27,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10797,
#    'NewDeaths': 0,
#    'TotalDeaths': 236,
#    'NewRecovered': 0,
#    'TotalRecovered': 1159,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Jersey',
#    'CountryCode': 'JE',
#    'Slug': 'jersey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 425,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 6,
#    'TotalRecovered': 282,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 176,
#    'TotalConfirmed': 1852,
#    'NewDeaths': 2,
#    'TotalDeaths': 19,
#    'NewRecovered': 47,
#    'TotalRecovered': 447,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 11,
#    'TotalConfirmed': 281,
#    'NewDeaths': 0,
#    'TotalDeaths': 14,
#    'NewRecovered': 2,
#    'TotalRecovered': 69,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Kiribati',
#    'CountryCode': 'KI',
#    'Slug': 'kiribati',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Korea (North)',
#    'CountryCode': 'KP',
#    'Slug': 'korea-north',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 10674,
#    'NewDeaths': 2,
#    'TotalDeaths': 236,
#    'NewRecovered': 72,
#    'TotalRecovered': 8114,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 80,
#    'TotalConfirmed': 1995,
#    'NewDeaths': 2,
#    'TotalDeaths': 9,
#    'NewRecovered': 62,
#    'TotalRecovered': 367,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 568,
#    'NewDeaths': 2,
#    'TotalDeaths': 7,
#    'NewRecovered': 68,
#    'TotalRecovered': 201,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 739,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 0,
#    'TotalRecovered': 88,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 677,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 1,
#    'TotalRecovered': 103,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 99,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 0,
#    'TotalRecovered': 7,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 51,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 4,
#    'TotalRecovered': 15,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 81,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 55,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 28,
#    'TotalConfirmed': 1326,
#    'NewDeaths': 2,
#    'TotalDeaths': 37,
#    'NewRecovered': 0,
#    'TotalRecovered': 242,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 3558,
#    'NewDeaths': 2,
#    'TotalDeaths': 75,
#    'NewRecovered': 10,
#    'TotalRecovered': 637,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Macao, SAR China',
#    'CountryCode': 'MO',
#    'Slug': 'macao-sar-china',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 18,
#    'TotalConfirmed': 1225,
#    'NewDeaths': 3,
#    'TotalDeaths': 54,
#    'NewRecovered': 21,
#    'TotalRecovered': 200,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 121,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 2,
#    'TotalRecovered': 41,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 36,
#    'TotalConfirmed': 5425,
#    'NewDeaths': 0,
#    'TotalDeaths': 89,
#    'NewRecovered': 98,
#    'TotalRecovered': 3295,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 17,
#    'TotalConfirmed': 69,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 16,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 22,
#    'TotalConfirmed': 246,
#    'NewDeaths': 0,
#    'TotalDeaths': 14,
#    'NewRecovered': 14,
#    'TotalRecovered': 56,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 431,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 8,
#    'TotalRecovered': 126,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Martinique',
#    'CountryCode': 'MQ',
#    'Slug': 'martinique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 6,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 328,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 16,
#    'TotalRecovered': 224,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Mayotte',
#    'CountryCode': 'YT',
#    'Slug': 'mayotte',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 764,
#    'TotalConfirmed': 8261,
#    'NewDeaths': 36,
#    'TotalDeaths': 686,
#    'NewRecovered': 0,
#    'TotalRecovered': 2627,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Micronesia, Federated States of',
#    'CountryCode': 'FM',
#    'Slug': 'micronesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 76,
#    'TotalConfirmed': 2548,
#    'NewDeaths': 3,
#    'TotalDeaths': 70,
#    'NewRecovered': 0,
#    'TotalRecovered': 457,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 94,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 1,
#    'TotalRecovered': 23,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 33,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 7,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 312,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 33,
#    'TotalRecovered': 88,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Montserrat',
#    'CountryCode': 'MS',
#    'Slug': 'montserrat',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 191,
#    'TotalConfirmed': 3046,
#    'NewDeaths': 2,
#    'TotalDeaths': 143,
#    'NewRecovered': 23,
#    'TotalRecovered': 350,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 8,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 119,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 0,
#    'TotalRecovered': 7,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 6,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Nauru',
#    'CountryCode': 'NR',
#    'Slug': 'nauru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 31,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 4,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 750,
#    'TotalConfirmed': 33588,
#    'NewDeaths': 67,
#    'TotalDeaths': 3764,
#    'NewRecovered': 0,
#    'TotalRecovered': 322,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Netherlands Antilles',
#    'CountryCode': 'AN',
#    'Slug': 'netherlands-antilles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'New Caledonia',
#    'CountryCode': 'NC',
#    'Slug': 'new-caledonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 1440,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 62,
#    'TotalRecovered': 974,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 6,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 648,
#    'NewDeaths': 0,
#    'TotalDeaths': 20,
#    'NewRecovered': 0,
#    'TotalRecovered': 117,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 38,
#    'TotalConfirmed': 665,
#    'NewDeaths': 1,
#    'TotalDeaths': 22,
#    'NewRecovered': 18,
#    'TotalRecovered': 188,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Niue',
#    'CountryCode': 'NU',
#    'Slug': 'niue',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Norfolk Island',
#    'CountryCode': 'NF',
#    'Slug': 'norfolk-island',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Northern Mariana Islands',
#    'CountryCode': 'MP',
#    'Slug': 'northern-mariana-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 78,
#    'TotalConfirmed': 7156,
#    'NewDeaths': 16,
#    'TotalDeaths': 181,
#    'NewRecovered': 0,
#    'TotalRecovered': 32,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 144,
#    'TotalConfirmed': 1410,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 5,
#    'TotalRecovered': 238,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 70,
#    'TotalConfirmed': 8418,
#    'NewDeaths': 8,
#    'TotalDeaths': 176,
#    'NewRecovered': 102,
#    'TotalRecovered': 1970,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Palau',
#    'CountryCode': 'PW',
#    'Slug': 'palau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 449,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 71,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 194,
#    'TotalConfirmed': 4467,
#    'NewDeaths': 6,
#    'TotalDeaths': 126,
#    'NewRecovered': 25,
#    'TotalRecovered': 165,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 208,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 5,
#    'TotalRecovered': 46,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 697,
#    'TotalConfirmed': 16325,
#    'NewDeaths': 45,
#    'TotalDeaths': 445,
#    'NewRecovered': 157,
#    'TotalRecovered': 6968,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 200,
#    'TotalConfirmed': 6459,
#    'NewDeaths': 19,
#    'TotalDeaths': 428,
#    'NewRecovered': 41,
#    'TotalRecovered': 613,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Pitcairn',
#    'CountryCode': 'PN',
#    'Slug': 'pitcairn',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 306,
#    'TotalConfirmed': 9593,
#    'NewDeaths': 20,
#    'TotalDeaths': 380,
#    'NewRecovered': 93,
#    'TotalRecovered': 1133,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 657,
#    'TotalConfirmed': 20863,
#    'NewDeaths': 21,
#    'TotalDeaths': 735,
#    'NewRecovered': 0,
#    'TotalRecovered': 610,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Puerto Rico',
#    'CountryCode': 'PR',
#    'Slug': 'puerto-rico',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 567,
#    'TotalConfirmed': 6015,
#    'NewDeaths': 1,
#    'TotalDeaths': 9,
#    'NewRecovered': 37,
#    'TotalRecovered': 555,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 510,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 0,
#    'TotalRecovered': 93,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 190,
#    'TotalConfirmed': 8936,
#    'NewDeaths': 27,
#    'TotalDeaths': 478,
#    'NewRecovered': 125,
#    'TotalRecovered': 2017,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 4268,
#    'TotalConfirmed': 47121,
#    'NewDeaths': 44,
#    'TotalDeaths': 405,
#    'NewRecovered': 155,
#    'TotalRecovered': 3446,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 147,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 76,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Réunion',
#    'CountryCode': 'RE',
#    'Slug': 'réunion',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Saint Helena',
#    'CountryCode': 'SH',
#    'Slug': 'saint-helena',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 15,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 2,
#    'TotalRecovered': 13,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Saint Pierre and Miquelon',
#    'CountryCode': 'PM',
#    'Slug': 'saint-pierre-and-miquelon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Saint-Barthélemy',
#    'CountryCode': 'BL',
#    'Slug': 'saint-barthélemy',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Saint-Martin (French part)',
#    'CountryCode': 'MF',
#    'Slug': 'saint-martin-french-part',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 462,
#    'NewDeaths': 0,
#    'TotalDeaths': 39,
#    'NewRecovered': 1,
#    'TotalRecovered': 61,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 1122,
#    'TotalConfirmed': 10484,
#    'NewDeaths': 6,
#    'TotalDeaths': 103,
#    'NewRecovered': 92,
#    'TotalRecovered': 1490,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 377,
#    'NewDeaths': 2,
#    'TotalDeaths': 5,
#    'NewRecovered': 15,
#    'TotalRecovered': 235,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 312,
#    'TotalConfirmed': 6630,
#    'NewDeaths': 3,
#    'TotalDeaths': 125,
#    'NewRecovered': 117,
#    'TotalRecovered': 870,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 5,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 43,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 6,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 1426,
#    'TotalConfirmed': 8014,
#    'NewDeaths': 0,
#    'TotalDeaths': 11,
#    'NewRecovered': 33,
#    'TotalRecovered': 801,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 1173,
#    'NewDeaths': 1,
#    'TotalDeaths': 13,
#    'NewRecovered': 22,
#    'TotalRecovered': 251,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 1335,
#    'NewDeaths': 3,
#    'TotalDeaths': 77,
#    'NewRecovered': 1,
#    'TotalRecovered': 193,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 73,
#    'TotalConfirmed': 237,
#    'NewDeaths': 1,
#    'TotalDeaths': 8,
#    'NewRecovered': 1,
#    'TotalRecovered': 4,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 142,
#    'TotalConfirmed': 3300,
#    'NewDeaths': 4,
#    'TotalDeaths': 58,
#    'NewRecovered': 152,
#    'TotalRecovered': 1055,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'South Georgia and the South Sandwich Islands',
#    'CountryCode': 'GS',
#    'Slug': 'south-georgia-and-the-south-sandwich-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 1536,
#    'TotalConfirmed': 200210,
#    'NewDeaths': 399,
#    'TotalDeaths': 20852,
#    'NewRecovered': 3230,
#    'TotalRecovered': 80587,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 33,
#    'TotalConfirmed': 304,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 2,
#    'TotalRecovered': 98,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 41,
#    'TotalConfirmed': 107,
#    'NewDeaths': 2,
#    'TotalDeaths': 12,
#    'NewRecovered': 2,
#    'TotalRecovered': 8,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 6,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Svalbard and Jan Mayen Islands',
#    'CountryCode': 'SJ',
#    'Slug': 'svalbard-and-jan-mayen-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 24,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 8,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 392,
#    'TotalConfirmed': 14777,
#    'NewDeaths': 40,
#    'TotalDeaths': 1580,
#    'NewRecovered': 0,
#    'TotalRecovered': 550,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 204,
#    'TotalConfirmed': 27944,
#    'NewDeaths': 36,
#    'TotalDeaths': 1429,
#    'NewRecovered': 800,
#    'TotalRecovered': 18600,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 5,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 422,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 14,
#    'TotalRecovered': 203,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 84,
#    'TotalConfirmed': 254,
#    'NewDeaths': 3,
#    'TotalDeaths': 10,
#    'NewRecovered': 0,
#    'TotalRecovered': 11,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 27,
#    'TotalConfirmed': 2792,
#    'NewDeaths': 0,
#    'TotalDeaths': 47,
#    'NewRecovered': 71,
#    'TotalRecovered': 1999,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 22,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 84,
#    'NewDeaths': 1,
#    'TotalDeaths': 6,
#    'NewRecovered': 1,
#    'TotalRecovered': 53,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Tokelau',
#    'CountryCode': 'TK',
#    'Slug': 'tokelau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Tonga',
#    'CountryCode': 'TO',
#    'Slug': 'tonga',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 114,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 1,
#    'TotalRecovered': 22,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 884,
#    'NewDeaths': 0,
#    'TotalDeaths': 38,
#    'NewRecovered': 105,
#    'TotalRecovered': 148,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 4674,
#    'TotalConfirmed': 90980,
#    'NewDeaths': 123,
#    'TotalDeaths': 2140,
#    'NewRecovered': 1454,
#    'TotalRecovered': 13430,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Turkmenistan',
#    'CountryCode': 'TM',
#    'Slug': 'turkmenistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Turks and Caicos Islands',
#    'CountryCode': 'TC',
#    'Slug': 'turks-and-caicos-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Tuvalu',
#    'CountryCode': 'TV',
#    'Slug': 'tuvalu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'US Minor Outlying Islands',
#    'CountryCode': 'UM',
#    'Slug': 'us-minor-outlying-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 56,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 10,
#    'TotalRecovered': 38,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 261,
#    'TotalConfirmed': 5710,
#    'NewDeaths': 10,
#    'TotalDeaths': 151,
#    'NewRecovered': 12,
#    'TotalRecovered': 359,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 484,
#    'TotalConfirmed': 7265,
#    'NewDeaths': 2,
#    'TotalDeaths': 43,
#    'NewRecovered': 74,
#    'TotalRecovered': 1360,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 4684,
#    'TotalConfirmed': 125856,
#    'NewDeaths': 455,
#    'TotalDeaths': 16550,
#    'NewRecovered': 10,
#    'TotalRecovered': 446,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 25231,
#    'TotalConfirmed': 783710,
#    'NewDeaths': 1431,
#    'TotalDeaths': 42075,
#    'NewRecovered': 1992,
#    'TotalRecovered': 72329,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 18,
#    'TotalConfirmed': 535,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 15,
#    'TotalRecovered': 313,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 62,
#    'TotalConfirmed': 1627,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 36,
#    'TotalRecovered': 261,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 256,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 0,
#    'TotalRecovered': 117,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 268,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 12,
#    'TotalRecovered': 214,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Virgin Islands, US',
#    'CountryCode': 'VI',
#    'Slug': 'virgin-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Wallis and Futuna Islands',
#    'CountryCode': 'WF',
#    'Slug': 'wallis-and-futuna-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Western Sahara',
#    'CountryCode': 'EH',
#    'Slug': 'western-sahara',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 65,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 2,
#    'TotalRecovered': 35,
#    'Date': '2020-04-21T21:32:40Z'},
#   {'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-21T21:32:40Z'}],
#  'Date': '2020-04-21T21:32:40Z'}

# %%
New_Confirmed = summary['Global']['NewConfirmed']
Total_Confirmed = summary['Global']['TotalConfirmed']
New_Deaths = summary['Global']['NewDeaths']
Total_Deaths = summary['Global']['TotalDeaths']
New_Recovered = summary['Global']['NewRecovered']
Total_Recovered = summary['Global']['TotalRecovered']
print("New COVID19 Reports")
Overall_df = pd.DataFrame({'NewConfirmed': [New_Confirmed],'TotalConfirmed': [Total_Confirmed],'NewDeaths': [New_Deaths],'TotalDeaths': [Total_Deaths],'NewRecovered': [New_Recovered],'TotalRecovered': [Total_Recovered]})
Overall_df
# Out:
# New COVID19 Reports
#    NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  \
# 0         70871         2470922       4940       169952         21835
#
#    TotalRecovered
# 0          645094

# %%
def GetCountries():
    response = requests.get('https://api.covid19api.com/summary')
    data_dict = response.json()
    countries = data_dict['Countries']
    return countries
countries = GetCountries()
country_df = pd.DataFrame(countries)
country_df
# Out:
#                        Country CountryCode                       Slug  \
# 0            ALA Aland Islands          AX          ala-aland-islands
# 1                  Afghanistan          AF                afghanistan
# 2                      Albania          AL                    albania
# 3                      Algeria          DZ                    algeria
# 4               American Samoa          AS             american-samoa
# ..                         ...         ...                        ...
# 243  Wallis and Futuna Islands          WF  wallis-and-futuna-islands
# 244             Western Sahara          EH             western-sahara
# 245                      Yemen          YE                      yemen
# 246                     Zambia          ZM                     zambia
# 247                   Zimbabwe          ZW                   zimbabwe
#
#      NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  \
# 0               0               0          0            0             0
# 1              30            1026          3           36             4
# 2              22             584          0           26            13
# 3              89            2718          9          384            52
# 4               0               0          0            0             0
# ..            ...             ...        ...          ...           ...
# 243             0               0          0            0             0
# 244             0               6          0            0             0
# 245             0               1          0            0             0
# 246             4              65          0            3             2
# 247             0              25          0            3             0
#
#      TotalRecovered                  Date
# 0                 0  2020-04-21T23:14:21Z
# 1               135  2020-04-21T23:14:21Z
# 2               327  2020-04-21T23:14:21Z
# 3              1099  2020-04-21T23:14:21Z
# 4                 0  2020-04-21T23:14:21Z
# ..              ...                   ...
# 243               0  2020-04-21T23:14:21Z
# 244               0  2020-04-21T23:14:21Z
# 245               0  2020-04-21T23:14:21Z
# 246              35  2020-04-21T23:14:21Z
# 247               2  2020-04-21T23:14:21Z
#
# [248 rows x 10 columns]

# %%
top = country_df.sort_values(input('Enter TotalConfirmed, NewConfirmed, NewDeaths, TotalDeaths, NewRecovered, or TotalRecovered view top20 countries: '), ascending = False)
top.head(20)
# Out:
# Enter TotalConfirmed, NewConfirmed, NewDeaths, TotalDeaths, NewRecovered, or TotalRecovered view top20 countries: TotalRecovered
#                        Country CountryCode           Slug  NewConfirmed  \
# 81                     Germany          DE        germany          1881
# 208                      Spain          ES          spain          1536
# 45                       China          CN          china            12
# 236   United States of America          US  united-states         25231
# 103  Iran, Islamic Republic of          IR           iran          1294
# 108                      Italy          IT          italy          2256
# 74                      France          FR         france          2383
# 30                      Brazil          BR         brazil          2089
# 215                Switzerland          CH    switzerland           204
# 227                     Turkey          TR         turkey          4674
# 39                      Canada          CA         canada          2025
# 14                     Austria          AT        austria            46
# 21                     Belgium          BE        belgium          1487
# 117              Korea (South)          KR    korea-south            13
# 173                       Peru          PE           peru           697
# 44                       Chile          CL          chile           419
# 59                     Denmark          DK        denmark           131
# 13                   Australia          AU      australia             0
# 107                     Israel          IL         israel           222
# 182         Russian Federation          RU         russia          4268
#
#      TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 81           147065        276         4862          3500           91500
# 208          200210        399        20852          3230           80587
# 45            83817          0         4636            55           77745
# 236          783710       1431        42075          1992           72329
# 103           83505         91         5209          2250           59273
# 108          181228        454        24114          1822           48877
# 74           156480        548        20292           853           38036
# 30            40743        125         2587             0           22130
# 215           27944         36         1429           800           18600
# 227           90980        123         2140          1454           13430
# 39            37658        162         1726           696           12543
# 14            14795         18          470           130           10631
# 21            39983        145         5828           138            8895
# 117           10674          2          236            72            8114
# 173           16325         45          445           157            6968
# 44            10507          6          139           338            4676
# 59             7711          9          364           171            4499
# 13             6547          0           67             0            4124
# 107           13713          5          177           295            4049
# 182           47121         44          405           155            3446
#
#                      Date
# 81   2020-04-21T23:14:21Z
# 208  2020-04-21T23:14:21Z
# 45   2020-04-21T23:14:21Z
# 236  2020-04-21T23:14:21Z
# 103  2020-04-21T23:14:21Z
# 108  2020-04-21T23:14:21Z
# 74   2020-04-21T23:14:21Z
# 30   2020-04-21T23:14:21Z
# 215  2020-04-21T23:14:21Z
# 227  2020-04-21T23:14:21Z
# 39   2020-04-21T23:14:21Z
# 14   2020-04-21T23:14:21Z
# 21   2020-04-21T23:14:21Z
# 117  2020-04-21T23:14:21Z
# 173  2020-04-21T23:14:21Z
# 44   2020-04-21T23:14:21Z
# 59   2020-04-21T23:14:21Z
# 13   2020-04-21T23:14:21Z
# 107  2020-04-21T23:14:21Z
# 182  2020-04-21T23:14:21Z
